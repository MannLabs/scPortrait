# %% [markdown]
# # Example Notebook Running SPARCSpy on datasets with multiple images
#
# The SPARCSpy base Project class is focused on processing whole slide images. In case you want to process Image Datasets with multiple-images then you will need to use the SPARCSpy TimecourseProject class and associated methods. This tutorial will walk you through this process.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import pandas as pd
import sys
import h5py

from sparcscore.pipeline.project import TimecourseProject
from sparcscore.pipeline.workflows import  Multithreaded_Cytosol_Cellpose_Downsampling_TimecourseSegmentation
from sparcscore.pipeline.extraction import TimecourseHDF5CellExtraction
from sparcscore.pipeline.classification import CellFeaturizer

# %% [markdown]
# ## Some Helper Functions for visualization of results

# %%
from sparcscore.processing.preprocessing import percentile_normalization
def plot_seg_overlay_timecourse(project_path, channel_to_show = 0, seg_mask_to_show = 0, selection = None, return_fig = False):
    
    seg_path = f"{project_path}/segmentation/input_segmentation.h5"
    with h5py.File(seg_path, "r") as hf:
        segmentation = hf.get("segmentation")
        channels = hf.get("input_images")
        
        print(segmentation)
        print(channels)
        
        if selection is None:
            segmentation = segmentation[0, seg_mask_to_show, :, :]
            image = channels[0, channel_to_show, :, :]
            
            fig = plt.figure()
            plt.imshow(percentile_normalization(image), cmap = "Greys_r")
            plt.imshow(segmentation, alpha = 0.5, cmap = "jet")
            plt.axis("off")
        
        if return_fig:
            return(fig)

def visualize_single_cells(project_path, n_cells = 10):
    cells_path = f"{project_path}/extraction/data/single_cells.h5"
    
    with h5py.File(cells_path, "r") as hf:
        cells = hf.get("single_cell_data")
        n_channels = cells.shape[1]
        
        fig, axs = plt.subplots(n_cells, n_channels, figsize = (n_channels*1, n_cells*1))
        
        for i in range(n_cells):
            image = cells[i]
            for n in range(n_channels):
                axs[i, n].imshow(image[n])
                axs[i, n].axis("off")

# %% [markdown]
# ## Initialize a Project
#
# SPARCSpy works with a project structure that is kept the same across different projects. Each project contains all of the results from one run. Each Project has the same general structure:
#
#     .
#     ├── classification
#     │   └── classifier_name
#     │       └── processing.log
#     ├── config.yml
#     ├── extraction
#     ├── segmentation
#     └── processing.log
#
#
# At the beginning of a SPARCSpy analysis a new project is generated where configuration parameters are loaded from the config file. This determines how each processing step will be executed.Here is a minimal example including the different cellpose segmentation methods for TimecourseProjects.
#
#     ----------------
#     name: "HPA segmentation"
#     input_channels: 3
#     output_channels: 5 #always add 2 to the number of channels
#     Multithreaded_Cytosol_Cellpose_TimecourseSegmentation:
#         input_channels: 3
#         output_masks: 2
#         threads: 5 #the segmentation model is loaded for each segmentation process utilizing GPU memory. Depending on GPU size this needs to be adjusted
#         cache: "." #path to where intermediate results are written to memory mapped temp arrays
#         lower_quantile_normalization:   0.000
#         upper_quantile_normalization:   1.000
#         median_filter_size:   4
#         nucleus_segmentation:
#             model: "nuclei"
#             diameter: 400 #if this parameter is not set then cellpose will determine the diameter of the segemented shapes automatically
#         cytosol_segmentation:
#             model: "cyto2"
#             diameter: 700
#         chunk_size: 50
#         match_masks: True
#         filtering_threshold_mask_matching: 0.95
#         filter_masks_size: False
#     Multithreaded_Cytosol_Cellpose_Downsampling_TimecourseSegmentation:
#         input_channels: 3
#         output_masks: 2
#         threads: 5
#         cache: "."
#         lower_quantile_normalization:   0.000
#         upper_quantile_normalization:   1.000
#         median_filter_size:   4
#         nucleus_segmentation:
#             model: "nuclei"
#         cytosol_segmentation:
#             model: "cyto2"
#         chunk_size: 50
#         match_masks: True
#         filtering_threshold_mask_matching: 0.95
#         filter_masks_size: False
#         downsampling_factor: 10 #downsamples images before performing segmentation, the segmented masks are upscaled again to the original dimension
#         smoothing_kernel_size: 7
#     Cytosol_Cellpose_Downsampling_TimecourseSegmentation:
#         input_channels: 3
#         output_masks: 2
#         cache: "."
#         lower_quantile_normalization:   0.000
#         upper_quantile_normalization:   1.000
#         median_filter_size:   4
#         nucleus_segmentation:
#             model: "nuclei"
#         cytosol_segmentation:
#             model: "cyto2"
#         chunk_size: 50
#         match_masks: True
#         filtering_threshold_mask_matching: 0.95
#         filter_masks_size: False
#         downsampling_factor: 10
#         smoothing_kernel_size: 7
#     TimecourseHDF5CellExtraction:
#         compression: True
#         threads: 8 # threads used in multithreading
#         image_size: 512 # image size in pixel
#         cache: "."
#         hdf5_rdcc_nbytes: 5242880000 # 5gb 2048 * 2048 * 1250
#         hdf5_rdcc_w0: 1
#         hdf5_rdcc_nslots: 1250
#     CellFeaturizer:
#         channel_classification: 4
#         threads: 20
#         batch_size: 100
#         dataloader_worker_number: 5
#         inference_device: "cuda"
#         screen_label: "featurization_Ch4"

# %%
#initialize project
project_location = f"project"

project = TimecourseProject(os.path.abspath(project_location), 
                             config_path= "config_example6.yml", 
                             segmentation_f= Multithreaded_Cytosol_Cellpose_Downsampling_TimecourseSegmentation,
                             extraction_f = TimecourseHDF5CellExtraction,
                             classification_f = CellFeaturizer,
                             overwrite=False,
                             debug=False)
# Out:
# modifying config
# /Users/sophia/Documents/GitHub/SPARCSspatial/src/sparcscore/pipeline/project.py:154: UserWarning: There is already a directory in the location path
#   warnings.warn("There is already a directory in the location path")

# %% [markdown]
# ## Input Data Format
#
# SPARCSpy was optimized to work with Data generated using an Opera Phenix Microscope. Each Project class has several data_loader functions associated with it that can be used to load data from different sources. You can find the code under `src/sparcscore/project.py`. The Dataloaders that load images from files are optimzied for file_name notation generated by the Phenix and the associated processing scripts.
#
# Data Format for `load_input_from_files`:
#
#     .... main directory
#         - Row02_Well02_Row02_Well02
#             - Timepoint001_Row02_Well02_Alexa488_zstack001Row02_Well02.tif
#             - Timepoint001_Row02_Well02_mCherry_zstack001_r000_c000.tif
#             - Timepoint001_Row02_Well02_DAPI_zstack001_r000_c000.tif
#         - ...
#
# Alternatively you can load data from a numpy array using `load_input_from_array` which can be used more flexibly to write your own dataloader:
#
# - images needs to be supplied in the shape (N, C, X, Y) to the parameter img
# - labels need to be supplied as a tidy dataframe to the parameter label. The first two columns of the dataframe need to contian the following information: row_index, unique Image ID. Then you can append as many additional labels as you want.
#
# Also feel free to submit a PR with a new dataloader for a common microscopy file format. Here we will demonstrate loading data using numpy to be more flexible to all data inputs.

# %% [markdown]
# ## Example loading data via a numpy array
#
# the timecourse SPARCSpy project expects images of the following format: NCYX.
#
# All of the images need to have the same dimensions and the same number of channels. The channels should be in the following order: nucleus, cytosol, other channels.
#
# The images need to have the dtype uint16.
#
# Here we have example code which reads RGB images (saved as PNGs), converts them to the expected format and loads them into a SPARCSpy timecourse project.

# %%
#read metadata of images
metadata = pd.read_csv("metadata.csv", index_col = 0)
metadata.head()
# Out:
#            gene_id   antibody species cell_line        organ cellosaurusID  \
# 0  ENSG00000000003  HPA004109   human      U2OS  Mesenchymal     CVCL_0042
# 1  ENSG00000000003  HPA004109   human      U2OS  Mesenchymal     CVCL_0042
# 2  ENSG00000000460  HPA024451   human      U2OS  Mesenchymal     CVCL_0042
# 3  ENSG00000000460  HPA024451   human      U2OS  Mesenchymal     CVCL_0042
# 4  ENSG00000000938  HPA002024   human      U2OS  Mesenchymal     CVCL_0042
#
#           location                                          image_URL  \
# 0          cytosol  http://images.proteinatlas.org/4109/23_H11_1_b...
# 1          cytosol  http://images.proteinatlas.org/4109/23_H11_2_b...
# 2              NaN  http://images.proteinatlas.org/24451/226_G2_1_...
# 3              NaN  http://images.proteinatlas.org/24451/226_G2_2_...
# 4  plasma membrane  http://images.proteinatlas.org/2024/59_H5_1_bl...
#
#      image_location
# 0  images/00005.jpg
# 1  images/00006.jpg
# 2  images/00017.jpg
# 3  images/00018.jpg
# 4  images/00023.jpg

# %%
#read images
from multiprocessing import Pool, get_context
from skimage.transform import resize
import platform

image_paths = metadata["image_location"]

#define a function to read the images, they need to be return as image stacks with each channel in a different dimension of the type np.uint16
def read_image(img):
    image = plt.imread(img)
    # convert from rgb to brg (nucleus, cytosol, other)
    image = np.roll(image, 1, 2)
    if image.shape[0] != 2048:
        image = resize(image, (2048, 2048)) #some of the images have different shapes so we force resize of those images that dont match the most common shape
    
    # convert from H x W x C to C x H x W
    image = np.moveaxis(image, [2, 0, 1], [0,  1, 2])
    image = image.astype("float64")
    image = (image/image.max()*65535).astype("uint16")  #normalize all images to the same range and then convert to uint16
    return image
context = "spawn" if platform.system() == 'Windows'else "fork"

with get_context(context).Pool(processes=12) as pool:
    images = pool.map(read_image, image_paths)
    images = np.stack(images)

# %% [markdown]
# The images have the expected shape (10 images, 3 channels, 2048px, 2048px) and look as expected

# %%
print(images.shape)
print(images.dtype)

for i in images[0:3]:
    fig, axs = plt.subplots(1, 3)
    axs[0].imshow(i[0])
    axs[0].axis("off")
    axs[1].imshow(i[1])
    axs[1].axis("off")
    axs[2].imshow(i[2])
    axs[2].axis("off")
# Out:
# (10, 3, 2048, 2048)
# uint16

# %%
#format the metadata to the expected format
metadata = metadata.reset_index()
metadata = metadata.get(["index", "image_URL", 'gene_id', 'antibody', 'species', 'cell_line', 'organ', 'cellosaurusID']) #here we use the image_URL as a unqiue image id

# %%
#load data into sparcspy
project.load_input_from_array(images, 
                             label = metadata,
                             overwrite = True)

# %% [markdown]
# Images and labels are written to the `input_segmentation.h5` HDF5 file contained under segmentation in the project folder.
# The input images are written to the container "input_images" and the labels to "labels". Column names are saved in a seperate dataset with the name "label_names".

# %%
with h5py.File(f"{project_location}/segmentation/input_segmentation.h5") as hf:
    print(hf.get("input_images"))
    print(hf.get("labels"))
    
    print("Example Label Dataset")
    print(hf.get("label_names")[:])
    print(hf.get("labels")[:])
# Out:
# <HDF5 dataset "input_images": shape (10, 3, 2048, 2048), type "<u2">
# <HDF5 dataset "labels": shape (10, 8), type "|O">
# Example Label Dataset
# [b'index' b'image_URL' b'gene_id' b'antibody' b'species' b'cell_line'
#  b'organ' b'cellosaurusID']
# [[b'0' b'http://images.proteinatlas.org/4109/23_H11_1_blue_red_green.jpg'
#   b'ENSG00000000003' b'HPA004109' b'human' b'U2OS' b'Mesenchymal'
#   b'CVCL_0042']
#  [b'1' b'http://images.proteinatlas.org/4109/23_H11_2_blue_red_green.jpg'
#   b'ENSG00000000003' b'HPA004109' b'human' b'U2OS' b'Mesenchymal'
#   b'CVCL_0042']
#  [b'2'
#   b'http://images.proteinatlas.org/24451/226_G2_1_blue_red_green.jpg'
#   b'ENSG00000000460' b'HPA024451' b'human' b'U2OS' b'Mesenchymal'
#   b'CVCL_0042']
#  [b'3'
#   b'http://images.proteinatlas.org/24451/226_G2_2_blue_red_green.jpg'
#   b'ENSG00000000460' b'HPA024451' b'human' b'U2OS' b'Mesenchymal'
#   b'CVCL_0042']
#  [b'4' b'http://images.proteinatlas.org/2024/59_H5_1_blue_red_green.jpg'
#   b'ENSG00000000938' b'HPA002024' b'human' b'U2OS' b'Mesenchymal'
#   b'CVCL_0042']
#  [b'5' b'http://images.proteinatlas.org/2024/59_H5_2_blue_red_green.jpg'
#   b'ENSG00000000938' b'HPA002024' b'human' b'U2OS' b'Mesenchymal'
#   b'CVCL_0042']
#  [b'6'
#   b'http://images.proteinatlas.org/38922/603_A5_1_blue_red_green.jpg'
#   b'ENSG00000000971' b'HPA038922' b'human' b'U2OS' b'Mesenchymal'
#   b'CVCL_0042']
#  [b'7'
#   b'http://images.proteinatlas.org/38922/603_A5_2_blue_red_green.jpg'
#   b'ENSG00000000971' b'HPA038922' b'human' b'U2OS' b'Mesenchymal'
#   b'CVCL_0042']
#  [b'8' b'http://images.proteinatlas.org/9569/931_H5_3_blue_red_green.jpg'
#   b'ENSG00000001084' b'CAB009569' b'human' b'U2OS' b'Mesenchymal'
#   b'CVCL_0042']
#  [b'9' b'http://images.proteinatlas.org/9569/931_H5_4_blue_red_green.jpg'
#   b'ENSG00000001084' b'CAB009569' b'human' b'U2OS' b'Mesenchymal'
#   b'CVCL_0042']]

# %% [markdown]
# ## Segmentation
#
# SPARCSpy has different segmentation workflows between which you can choose. If you run a timecourse project you will need to also select a timecourse segementation method.
#
# **notes on cellpose segmentation methods:**
#
# Cellpose currently does not allow for the processing of image batches. Each image will thus be segmented individually on the GPU. In case you have large images this isnt an issue since the GPU is still fully utilzed (the sharding parameter can be used to set an optimal shard size for maximizing GPU utilization). For a large quantity of small images this leads to a very inefficient processing. To improve the speed a bit you can try running with multiple threads. Each thread will also load the model though so it requires quite some Memory overhead. This is hopefully an issue we can address in future releases. If its something you would like to work on get in touch with the developers we are happy for help!

# %%
project.segment(debug = True)
# Out:
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Multithreaded_Cytosol_Cellpose_Downsampling_TimecourseSegmentation_t6kor5kg for Multithreaded_Cytosol_Cellpose_Downsampling_TimecourseSegmentation
# Generating Shards:   0%|          | 0/10 [00:00<?, ?it/s]
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_m4khihns for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_d21qdqua for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_bm12gxzx for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_uerhpi_m for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_ha6a2178 for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_67_us34q for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_9lbs2ftj for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_mx2i7hgd for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_hmooj6ve for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:12] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_g3n3wpth for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:12] Shard list created with 10 elements.
# [22/07/2024 16:38:12] Beginning segmentation with 5 threads.
# [22/07/2024 16:38:12] A total of 10 processes need to be executed.
# [22/07/2024 16:38:12] Beginning segmentation on 1 available GPUs.
#   0%|          | 0/10 [00:00<?, ?it/s]
# [22/07/2024 16:38:15] Segmentation on index 1 started.
# [22/07/2024 16:38:15] Segmentation on index 0 started.
# [22/07/2024 16:38:15] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_t001acg_ for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:15] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_k3zk8_kb for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:15] Segmentation on index 3 started.
# [22/07/2024 16:38:15] Segmentation on index 2 started.
# [22/07/2024 16:38:15] Segmentation on index 4 started.
# [22/07/2024 16:38:15] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_fuhrxqn_ for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:15] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_6tdflkpr for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:15] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_t9sz0idi for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:15] Performing image padding to ensure that image is compatible with selected downsample kernel size of 10.
# [22/07/2024 16:38:15] Downsampling image by a factor of 10x10
# [22/07/2024 16:38:15] Performing image padding to ensure that image is compatible with selected downsample kernel size of 10.
# [22/07/2024 16:38:15] Downsampling image by a factor of 10x10
# [22/07/2024 16:38:15] Performing image padding to ensure that image is compatible with selected downsample kernel size of 10.
# [22/07/2024 16:38:15] Downsampling image by a factor of 10x10
# [22/07/2024 16:38:15] Performing image padding to ensure that image is compatible with selected downsample kernel size of 10.
# [22/07/2024 16:38:15] GPU Status for segmentation is True and will segment using the following device mps.
# [22/07/2024 16:38:15] GPU Status for segmentation is True and will segment using the following device mps.
# [22/07/2024 16:38:15] Downsampling image by a factor of 10x10
# [22/07/2024 16:38:15] Performing image padding to ensure that image is compatible with selected downsample kernel size of 10.
# [22/07/2024 16:38:15] Downsampling image by a factor of 10x10
# [22/07/2024 16:38:15] GPU Status for segmentation is True and will segment using the following device mps.
# [22/07/2024 16:38:15] GPU Status for segmentation is True and will segment using the following device mps.
# [22/07/2024 16:38:15] GPU Status for segmentation is True and will segment using the following device mps.
# [22/07/2024 16:38:16] Segmenting nucleus using the following model: nuclei
# [22/07/2024 16:38:16] Segmenting nucleus using the following model: nuclei
# [22/07/2024 16:38:16] Segmenting nucleus using the following model: nuclei
# [22/07/2024 16:38:16] Segmenting nucleus using the following model: nuclei
# [22/07/2024 16:38:16] Segmenting nucleus using the following model: nuclei
# [22/07/2024 16:38:17] Segmenting cytosol using the following model: cyto2
# [22/07/2024 16:38:17] Segmenting cytosol using the following model: cyto2
# [22/07/2024 16:38:18] Segmenting cytosol using the following model: cyto2
# [22/07/2024 16:38:18] Segmenting cytosol using the following model: cyto2
# [22/07/2024 16:38:18] Segmenting cytosol using the following model: cyto2
# [22/07/2024 16:38:18] Performing filtering to match Cytosol and Nucleus IDs.
# [22/07/2024 16:38:18] Removed 5 nuclei and 3 cytosols due to filtering.
# [22/07/2024 16:38:18] After filtering, 10 matching nuclei and cytosol masks remain.
# [22/07/2024 16:38:18] Performing filtering to match Cytosol and Nucleus IDs.
# [22/07/2024 16:38:18] Removed 6 nuclei and 1 cytosols due to filtering.
# [22/07/2024 16:38:18] After filtering, 4 matching nuclei and cytosol masks remain.
# [22/07/2024 16:38:18] Performing filtering to match Cytosol and Nucleus IDs.
# [22/07/2024 16:38:18] Removed 1 nuclei and 0 cytosols due to filtering.
# [22/07/2024 16:38:18] After filtering, 8 matching nuclei and cytosol masks remain.
# [22/07/2024 16:38:18] Performing filtering to match Cytosol and Nucleus IDs.
# [22/07/2024 16:38:18] Removed 3 nuclei and 0 cytosols due to filtering.
# [22/07/2024 16:38:18] After filtering, 11 matching nuclei and cytosol masks remain.
# [22/07/2024 16:38:18] Performing filtering to match Cytosol and Nucleus IDs.
# [22/07/2024 16:38:18] Removed 2 nuclei and 0 cytosols due to filtering.
# [22/07/2024 16:38:18] After filtering, 2 matching nuclei and cytosol masks remain.
# [22/07/2024 16:38:18] Total time to perform nucleus and cytosol mask matching filtering: 0.31 seconds
# [22/07/2024 16:38:18] Total time to perform nucleus and cytosol mask matching filtering: 0.32 seconds
# [22/07/2024 16:38:18] Total time to perform nucleus and cytosol mask matching filtering: 0.33 seconds
# [22/07/2024 16:38:18] Total time to perform nucleus and cytosol mask matching filtering: 0.32 seconds
# [22/07/2024 16:38:18] Total time to perform nucleus and cytosol mask matching filtering: 0.33 seconds
# [22/07/2024 16:38:21] transferring 4 to temmporray memory mapped array
# [22/07/2024 16:38:21] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_t9sz0idi'>
# [22/07/2024 16:38:21] Temporary directory not found, skipping cleanup
# [22/07/2024 16:38:21] Segmentation on index 4 completed.
# [22/07/2024 16:38:21] Segmentation on index 5 started.
# [22/07/2024 16:38:21] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_6_80yv6c for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:21] transferring 1 to temmporray memory mapped array
# [22/07/2024 16:38:21] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_t001acg_'>
# [22/07/2024 16:38:21] Temporary directory not found, skipping cleanup
# [22/07/2024 16:38:21] Segmentation on index 1 completed.
# [22/07/2024 16:38:21] Segmentation on index 6 started.
# [22/07/2024 16:38:21] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_cso35161 for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:21] transferring 2 to temmporray memory mapped array
# [22/07/2024 16:38:21] transferring 3 to temmporray memory mapped array
# [22/07/2024 16:38:21] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_6tdflkpr'>
# [22/07/2024 16:38:21] Temporary directory not found, skipping cleanup
# [22/07/2024 16:38:21] Segmentation on index 2 completed.
# [22/07/2024 16:38:21] Segmentation on index 7 started.
# [22/07/2024 16:38:21] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_yqmqmuyx for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:21] Performing image padding to ensure that image is compatible with selected downsample kernel size of 10.
# [22/07/2024 16:38:21] Downsampling image by a factor of 10x10
# [22/07/2024 16:38:21] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_fuhrxqn_'>
# [22/07/2024 16:38:21] Temporary directory not found, skipping cleanup
# [22/07/2024 16:38:21] Segmentation on index 3 completed.
# [22/07/2024 16:38:21] Segmentation on index 8 started.
# [22/07/2024 16:38:21] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_zsf1tmuk for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:21] GPU Status for segmentation is True and will segment using the following device mps.
# [22/07/2024 16:38:21] transferring 0 to temmporray memory mapped array
# [22/07/2024 16:38:21] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_k3zk8_kb'>
# [22/07/2024 16:38:21] Temporary directory not found, skipping cleanup
# [22/07/2024 16:38:21] Segmentation on index 0 completed.
# [22/07/2024 16:38:21] Segmentation on index 9 started.
# [22/07/2024 16:38:21] Initialized temporary directory at /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_3f2tbvf1 for Cytosol_Segmentation_Downsampling_Cellpose_Timecourse
# [22/07/2024 16:38:21] Performing image padding to ensure that image is compatible with selected downsample kernel size of 10.
# [22/07/2024 16:38:21] Downsampling image by a factor of 10x10
# [22/07/2024 16:38:21] GPU Status for segmentation is True and will segment using the following device mps.
# [22/07/2024 16:38:21] Segmenting nucleus using the following model: nuclei
# [22/07/2024 16:38:21] Performing image padding to ensure that image is compatible with selected downsample kernel size of 10.
# [22/07/2024 16:38:21] Downsampling image by a factor of 10x10
# [22/07/2024 16:38:21] GPU Status for segmentation is True and will segment using the following device mps.
# [22/07/2024 16:38:21] Performing image padding to ensure that image is compatible with selected downsample kernel size of 10.
# [22/07/2024 16:38:21] Downsampling image by a factor of 10x10
# [22/07/2024 16:38:21] GPU Status for segmentation is True and will segment using the following device mps.
# [22/07/2024 16:38:21] Performing image padding to ensure that image is compatible with selected downsample kernel size of 10.
# [22/07/2024 16:38:21] Downsampling image by a factor of 10x10
# [22/07/2024 16:38:21] GPU Status for segmentation is True and will segment using the following device mps.
# [22/07/2024 16:38:22] Segmenting nucleus using the following model: nuclei
# [22/07/2024 16:38:22] Segmenting nucleus using the following model: nuclei
# [22/07/2024 16:38:22] Segmenting nucleus using the following model: nuclei
# [22/07/2024 16:38:22] Segmenting nucleus using the following model: nuclei
# [22/07/2024 16:38:22] Segmenting cytosol using the following model: cyto2
# [22/07/2024 16:38:22] Segmenting cytosol using the following model: cyto2
# [22/07/2024 16:38:22] Segmenting cytosol using the following model: cyto2
# [22/07/2024 16:38:22] Segmenting cytosol using the following model: cyto2
# [22/07/2024 16:38:22] Segmenting cytosol using the following model: cyto2
# [22/07/2024 16:38:22] Performing filtering to match Cytosol and Nucleus IDs.
# [22/07/2024 16:38:22] Removed 3 nuclei and 4 cytosols due to filtering.
# [22/07/2024 16:38:22] After filtering, 6 matching nuclei and cytosol masks remain.
# [22/07/2024 16:38:22] Performing filtering to match Cytosol and Nucleus IDs.
# [22/07/2024 16:38:22] Removed 1 nuclei and 2 cytosols due to filtering.
# [22/07/2024 16:38:22] After filtering, 5 matching nuclei and cytosol masks remain.
# [22/07/2024 16:38:22] Performing filtering to match Cytosol and Nucleus IDs.
# [22/07/2024 16:38:22] Removed 1 nuclei and 0 cytosols due to filtering.
# [22/07/2024 16:38:22] After filtering, 6 matching nuclei and cytosol masks remain.
# [22/07/2024 16:38:22] Total time to perform nucleus and cytosol mask matching filtering: 0.20 seconds
# [22/07/2024 16:38:22] Performing filtering to match Cytosol and Nucleus IDs.
# [22/07/2024 16:38:22] Removed 3 nuclei and 0 cytosols due to filtering.
# [22/07/2024 16:38:22] After filtering, 14 matching nuclei and cytosol masks remain.
# [22/07/2024 16:38:22] Total time to perform nucleus and cytosol mask matching filtering: 0.19 seconds
# [22/07/2024 16:38:23] Total time to perform nucleus and cytosol mask matching filtering: 0.20 seconds
# [22/07/2024 16:38:23] Performing filtering to match Cytosol and Nucleus IDs.
# [22/07/2024 16:38:23] Removed 6 nuclei and 1 cytosols due to filtering.
# [22/07/2024 16:38:23] After filtering, 11 matching nuclei and cytosol masks remain.
# [22/07/2024 16:38:23] Total time to perform nucleus and cytosol mask matching filtering: 0.20 seconds
# [22/07/2024 16:38:23] Total time to perform nucleus and cytosol mask matching filtering: 0.19 seconds
# [22/07/2024 16:38:25] transferring 5 to temmporray memory mapped array
# [22/07/2024 16:38:25] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_6_80yv6c'>
# [22/07/2024 16:38:25] Temporary directory not found, skipping cleanup
# [22/07/2024 16:38:25] Segmentation on index 5 completed.
# [22/07/2024 16:38:25] transferring 7 to temmporray memory mapped array
# [22/07/2024 16:38:25] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_yqmqmuyx'>
# [22/07/2024 16:38:25] Temporary directory not found, skipping cleanup
# [22/07/2024 16:38:25] Segmentation on index 7 completed.
# [22/07/2024 16:38:25] transferring 6 to temmporray memory mapped array
# [22/07/2024 16:38:25] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_cso35161'>
# [22/07/2024 16:38:25] Temporary directory not found, skipping cleanup
# [22/07/2024 16:38:25] Segmentation on index 6 completed.
# [22/07/2024 16:38:25] transferring 8 to temmporray memory mapped array
# [22/07/2024 16:38:25] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_zsf1tmuk'>
# [22/07/2024 16:38:25] Temporary directory not found, skipping cleanup
# [22/07/2024 16:38:25] Segmentation on index 8 completed.
# [22/07/2024 16:38:25] transferring 9 to temmporray memory mapped array
# [22/07/2024 16:38:25] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_3f2tbvf1'>
# [22/07/2024 16:38:25] Temporary directory not found, skipping cleanup
# [22/07/2024 16:38:25] Segmentation on index 9 completed.
# WARNING:root:Folder /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_6_80yv6c with temp mmap arrays is being deleted. All existing temp mmapp arrays will be unusable!
# WARNING:root:Folder /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_cso35161 with temp mmap arrays is being deleted. All existing temp mmapp arrays will be unusable!
# WARNING:root:Folder /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_yqmqmuyx with temp mmap arrays is being deleted. All existing temp mmapp arrays will be unusable!
# WARNING:root:Folder /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_zsf1tmuk with temp mmap arrays is being deleted. All existing temp mmapp arrays will be unusable!
# WARNING:root:Folder /var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Cytosol_Segmentation_Downsampling_Cellpose_Timecourse_3f2tbvf1 with temp mmap arrays is being deleted. All existing temp mmapp arrays will be unusable!
# All segmentations are done.
# [22/07/2024 16:38:26] Finished parallel segmentation
# [22/07/2024 16:38:26] Transferring results to array.
# [22/07/2024 16:38:26] resolve segmentation indexes
# Adjusting Indexes:   0%|          | 0/10 [00:00<?, ?it/s]
# [22/07/2024 16:38:28] Number of filtered classes combined after segmentation:
# [22/07/2024 16:38:28] 77
# [22/07/2024 16:38:28] Number of classes in contact with image edges:
# [22/07/2024 16:38:28] 0
# [22/07/2024 16:38:28] Number of classes after removing image edges:
# [22/07/2024 16:38:28] 77
# [22/07/2024 16:38:28] Saved cell_id classes to file /Users/sophia/Documents/GitHub/SPARCSspatial/example_data/example_6/project/segmentation/classes.csv.
# [22/07/2024 16:38:31] Sharding sanity check: edge classes are a full subset of all classes
# [22/07/2024 16:38:31] resolved segmentation list
# [22/07/2024 16:38:31] Adjusted Indexes.
# [22/07/2024 16:38:31] Cleaned up temporary directory at <TemporaryDirectory '/var/folders/35/p4c58_4n3bb0bxnzgns1t7kh0000gn/T/./Multithreaded_Cytosol_Cellpose_Downsampling_TimecourseSegmentation_t6kor5kg'>

# %% [markdown]
# Segmentation results are written to the `input_segmentation.h5` HDF5 file in a new data container called "segmentation".
# In addition a csv file called classes.csv is generated which contains all the cell_ids that are not located in image edges and will be further processed.
#
# If we look at the segmentation dataset we can see that it contains a numpy array containing two segmentation masks for each input image: the nuclear segmentation and the cytosol segmentation generated by our chosen segmentation method. If you use the method CytosolOnly both of the masks will be identical.

# %%
plot_seg_overlay_timecourse(project_location, channel_to_show = 0)
plot_seg_overlay_timecourse(project_location, channel_to_show=1)

plot_seg_overlay_timecourse(project_location, channel_to_show = 0, seg_mask_to_show = 1)
plot_seg_overlay_timecourse(project_location, channel_to_show=1, seg_mask_to_show = 1)
# Out:
# <HDF5 dataset "segmentation": shape (10, 2, 2048, 2048), type "<u4">
# <HDF5 dataset "input_images": shape (10, 3, 2048, 2048), type "<u2">
# <HDF5 dataset "segmentation": shape (10, 2, 2048, 2048), type "<u4">
# <HDF5 dataset "input_images": shape (10, 3, 2048, 2048), type "<u2">
# <HDF5 dataset "segmentation": shape (10, 2, 2048, 2048), type "<u4">
# <HDF5 dataset "input_images": shape (10, 3, 2048, 2048), type "<u2">
# <HDF5 dataset "segmentation": shape (10, 2, 2048, 2048), type "<u4">
# <HDF5 dataset "input_images": shape (10, 3, 2048, 2048), type "<u2">

# %% [markdown]
# ## Single-Cell Extraction

# %%
project.extract()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# The extracted single-cell images are written to a h5py file single_cells.h5 located under `extraction\data` within the project folder.
#
# The file contains four datasets: `single_cell_data`, `single_cell_index`, `single_cell_index_labelled`, `label_names`.
#
# `single_cell_data` contains the extracted single cell images while `single_cell_index` contains the cell id of the extracted cell at that location.
#
# The other two datacontainers integrated the labels from the base dataset and attach them to each cell.

# %%
with h5py.File(f"{project_location}/extraction/data/single_cells.h5")as hf:
    print(hf.keys())
    
    print(hf.get("label_names")[:])
    print(hf.get("single_cell_index_labelled")[2])
# Out:
# <KeysViewHDF5 ['label_names', 'single_cell_data', 'single_cell_index', 'single_cell_index_labelled']>
# [b'index' b'cellid' b'image_URL' b'gene_id' b'antibody' b'species'
#  b'cell_line' b'organ' b'cellosaurusID']
# [b'12' b'http://images.proteinatlas.org/4109/23_H11_2_blue_red_green.jpg'
#  b'ENSG00000000003' b'HPA004109' b'human' b'U2OS' b'Mesenchymal'
#  b'CVCL_0042']

# %%
# single cell index contains two columns, the first is the index position in the hdf5 datacontainer, the second is the cell id

with h5py.File(f"{project_location}/extraction/data/single_cells.h5")as hf:
    
    #print(hf["single_cell_index"][0:10])
    print(hf["single_cell_index"][2])
# Out:
# [ 2 12]

# %%
# single cell index labelled contains the same information as single_cell_index
# in the first two columns but adds additional columns with labelling information, the column names for
# the labelling information is contained in label_names

with h5py.File(f"{project_location}/extraction/data/single_cells.h5")as hf:
    
    print(hf["label_names"][:])
    print(hf["single_cell_index_labelled"][2])
# Out:
# [b'index' b'cellid' b'image_URL' b'gene_id' b'antibody' b'species'
#  b'cell_line' b'organ' b'cellosaurusID']
# [b'12' b'http://images.proteinatlas.org/4109/23_H11_2_blue_red_green.jpg'
#  b'ENSG00000000003' b'HPA004109' b'human' b'U2OS' b'Mesenchymal'
#  b'CVCL_0042']

# %%
visualize_single_cells(project_location)
